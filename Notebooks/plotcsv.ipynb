# %%
import pandas as pd

# %%
pd.read_csv('../Data/szenarios.csv')
# Out:
#              S1          S2         R  N   t
# 0    393.000000  293.000000  0.850000  0   0
# 1    452.771196  295.352645  0.867708  0   1
# 2    451.042279  295.589059  0.793863  0   2
# 3    438.425970  299.634439  0.751726  0   3
# 4    465.159525  314.795382  0.765126  0   4
# 5    493.145627  318.584765  0.772427  0   5
# 6    492.016869  323.586685  0.697598  0   6
# 7    508.208081  328.753193  0.674870  0   7
# 8    466.453550  343.358279  0.655745  0   8
# 9    473.396795  345.940172  0.609208  0   9
# 10   500.688429  353.727428  0.545334  0  10
# 11   509.323483  338.231408  0.515297  0  11
# 12   603.838490  353.162639  0.539165  0  12
# 13   586.901417  383.079978  0.542112  0  13
# 14   651.963435  369.690117  0.529152  0  14
# 15   485.403333  390.541778  0.477813  0  15
# 16   478.286683  405.076375  0.463363  0  16
# 17   561.503817  400.777682  0.503543  0  17
# 18   611.823769  401.110229  0.540473  0  18
# 19   626.163667  391.394406  0.510399  0  19
# ...

# %%
df = pd.read_csv('../Data/szenarios.csv')

# %%
df.plot()
